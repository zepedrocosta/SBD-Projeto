# %% [markdown]
# ## Maria DB - TPROC-C

# %% [markdown]
# Build Schema -> Options

# %% [markdown]
# Run this command in cmd:
# docker run -d --name mariadb-bench -e MYSQL_ROOT_PASSWORD=root -e MYSQL_DATABASE=tpcc -p 3306:3306 mariadb:latest
#
# Host: 10.0.2.2
#
# Nº of warehouses: 10
#
# Virtual users to build schema: 4
#
# Driver Script and Virtual User options are by default

# %% [markdown]
# ![Screenshot 2025-05-20 at 11-38-54 682C6702635803E203236323 Result.png](<attachment:Screenshot 2025-05-20 at 11-38-54 682C6702635803E203236323 Result.png>)

# %% [markdown]
# ![Screenshot 2025-05-20 at 14-30-53 682C6702635803E203236323 Transaction Count.png](<attachment:Screenshot 2025-05-20 at 14-30-53 682C6702635803E203236323 Transaction Count.png>)

# %% [markdown]
# With my.cnf configuration

# %% [markdown]
# [mysqld]
# innodb_buffer_pool_size=2G
# innodb_doublewrite=0
# innodb_read_io_threads=8
# innodb_write_io_threads=8
# max_connections=200
# skip-log-bin

# %% [markdown]
# Run this command in cmd:
# docker run -d --name mariadb-bench -e MYSQL_ROOT_PASSWORD=root -e MYSQL_DATABASE=tpcc -p 3306:3306 -v ~/OneDrive/Ambiente de Trabalho/Universidade/4ºAno-STD2-Rodrigo/2ºSemestre/SBD/Práticas/Projeto/my.cnf:/etc/mysql/conf.d/my.cnf:ro -v mariadb_data:/var/lib/mysql mariadb:latest
#
# Host: 10.0.2.2
#
# Nº of warehouses: 10
#
# Virtual users to build schema: 4
#
# Driver Script and Virtual User options are by default

# %% [markdown]
# ![Screenshot 2025-05-21 at 14-24-06 682DDFBC635A03E233034323 Result.png](<attachment:Screenshot 2025-05-21 at 14-24-06 682DDFBC635A03E233034323 Result.png>)

# %% [markdown]
# ![Screenshot 2025-05-21 at 14-24-24 682DDFBC635A03E233034323 Transaction Count.png](<attachment:Screenshot 2025-05-21 at 14-24-24 682DDFBC635A03E233034323 Transaction Count.png>)

# %% [markdown]
# With another configuration

# %% [markdown]
# [mysqld]
# innodb_buffer_pool_size = 4G
# innodb_log_file_size = 1G
# innodb_log_buffer_size = 64M
# innodb_flush_log_at_trx_commit = 2
# innodb_flush_method = O_DIRECT
# innodb_io_capacity = 1000
# innodb_io_capacity_max = 2000
# innodb_read_io_threads = 8
# innodb_write_io_threads = 8
# innodb_thread_concurrency = 0
# max_connections = 200
# table_open_cache = 2048
# query_cache_type = 0
# query_cache_size = 0
# performance_schema = OFF
# skip-log-bin

# %% [markdown]
# Host: 10.0.2.2
#
# Nº of warehouses: 10
#
# Virtual users to build schema: 4
#
# Driver Script and Virtual User options are by default

# %% [markdown]
# ![Screenshot 2025-05-21 at 16-24-08 682DFC50635A03E233635343 Result.png](<attachment:Screenshot 2025-05-21 at 16-24-08 682DFC50635A03E233635343 Result.png>)

# %% [markdown]
# ![Screenshot 2025-05-21 at 16-24-32 682DFC50635A03E233635343 Transaction Count.png](<attachment:Screenshot 2025-05-21 at 16-24-32 682DFC50635A03E233635343 Transaction Count.png>)

# %% [markdown]
# # MySQL - TPROC-C

# %% [markdown]
# Build Schema -> Options

# %% [markdown]
# Run this command in cmd:
# docker run -d --name mysql57-bench -e MYSQL_ROOT_PASSWORD=root -e MYSQL_DATABASE=tpcc -p 3306:3306 mysql:5.7
#
# Host: 10.0.2.2
#
# Nº of warehouses: 10
#
# Virtual users to build schema: 4
#
# Driver Script and Virtual User options are by default

# %% [markdown]
# ![Screenshot 2025-05-20 at 14-00-47 682C87EF635903E223334353 Result.png](<attachment:Screenshot 2025-05-20 at 14-00-47 682C87EF635903E223334353 Result.png>)

# %% [markdown]
# ![Screenshot 2025-05-20 at 14-30-14 682C87EF635903E223334353 Transaction Count.png](<attachment:Screenshot 2025-05-20 at 14-30-14 682C87EF635903E223334353 Transaction Count.png>)

# %% [markdown]
# With mysql.conf configuration

# %% [markdown]
# [mysqld]
# max_connections = 200
# innodb_buffer_pool_size = 1G
# innodb_log_file_size = 256M
# innodb_flush_log_at_trx_commit = 2
# query_cache_size = 0
# query_cache_type = 0
# tmp_table_size = 64M
# max_heap_table_size = 64M
# slow_query_log = 1
# long_query_time = 0.5

# %% [markdown]
# Run this command in cmd:
# docker run -d `
#   --name mysql-bench `
#   -e MYSQL_ROOT_PASSWORD=root `
#   -e MYSQL_DATABASE=tpcc `
#   -p 3306:3306 `
#   -v "/c/Users/digos/OneDrive/Ambiente de Trabalho/Universidade/4ºAno-STD2-Rodrigo/2ºSemestre/SBD/Práticas/Projeto/mysql-conf:/etc/mysql/conf.d:ro" `
#   -v mysql-data:/var/lib/mysql `
#   mysql:5.7
#
# Host: 10.0.2.2
#
# Nº of warehouses: 10
#
# Virtual users to build schema: 4
#
# Driver Script and Virtual User options are by default

# %% [markdown]
# ![Screenshot 2025-05-21 at 16-00-12 682DF6AE635A03E223932363 Result.png](<attachment:Screenshot 2025-05-21 at 16-00-12 682DF6AE635A03E223932363 Result.png>)

# %% [markdown]
# ![Screenshot 2025-05-21 at 16-00-21 682DF6AE635A03E223932363 Transaction Count.png](<attachment:Screenshot 2025-05-21 at 16-00-21 682DF6AE635A03E223932363 Transaction Count.png>)

# %% [markdown]
# With another configuration

# %% [markdown]
# [mysqld]
# max_connections = 200
# innodb_buffer_pool_size = 4G
# innodb_log_file_size = 1G
# innodb_log_buffer_size = 64M
# innodb_flush_log_at_trx_commit = 2
# innodb_flush_method = O_DIRECT
# innodb_io_capacity = 1000
# innodb_io_capacity_max = 2000
# innodb_thread_concurrency = 0
# tmp_table_size = 128M
# max_heap_table_size = 128M
# table_open_cache = 2048
# open_files_limit = 65535
# query_cache_type = 0
# query_cache_size = 0
# performance_schema = OFF
# skip-log-bin
# slow_query_log = 0

# %% [markdown]
# Host: 10.0.2.2
#
# Nº of warehouses: 10
#
# Virtual users to build schema: 4
#
# Driver Script and Virtual User options are by default

# %% [markdown]
# ![Screenshot 2025-05-23 at 11-42-13 68305D3F635C03E293332303 Result.png](<attachment:Screenshot 2025-05-23 at 11-42-13 68305D3F635C03E293332303 Result.png>)

# %% [markdown]
# ![Screenshot 2025-05-23 at 11-42-31 68305D3F635C03E293332303 Transaction Count.png](<attachment:Screenshot 2025-05-23 at 11-42-31 68305D3F635C03E293332303 Transaction Count.png>)

# %% [markdown]
# # PostgreSQL - TPROC-C

# %% [markdown]
# Build Schema -> Options

# %% [markdown]
# Run this command in cmd:
# docker run -d --name postgres-bench -e POSTGRES_PASSWORD=root -e POSTGRES_DB=tpcc -p 5432:5432 postgres:16
#
# Host: 10.0.2.2
#
# Nº of warehouses: 10
#
# Virtual users to build schema: 4
#
# Driver Script and Virtual User options are by default

# %% [markdown]
# ![Screenshot 2025-05-20 at 14-28-29 682C8F67635903E203439363 Result.png](<attachment:Screenshot 2025-05-20 at 14-28-29 682C8F67635903E203439363 Result.png>)

# %% [markdown]
# ![Screenshot 2025-05-20 at 14-29-08 682C8F67635903E203439363 Transaction Count.png](<attachment:Screenshot 2025-05-20 at 14-29-08 682C8F67635903E203439363 Transaction Count.png>)

# %% [markdown]
# With postgresql.conf configuration

# %% [markdown]
# listen_addresses = '*'
#
# shared_buffers = 1GB
# work_mem = 16MB
# maintenance_work_mem = 512MB
#
# wal_level = minimal
# synchronous_commit = off
# full_page_writes = off
# wal_buffers = 16MB
# max_wal_size = 1GB
# min_wal_size = 80MB
#
# max_connections = 200
# max_worker_processes = 8
# max_parallel_workers = 8
# max_parallel_workers_per_gather = 4
#
# random_page_cost = 1.1
# effective_cache_size = 3GB
#
# log_min_duration_statement = 500

# %% [markdown]
# Run this command in cmd:
# docker run -d `
#   --name pg-bench `
#   -e POSTGRES_PASSWORD=root `
#   -e POSTGRES_DB=tpcc `
#   -p 5432:5432 `
#   -v "/c/Users/digos/OneDrive/Ambiente de Trabalho/Universidade/4ºAno-STD2-Rodrigo/2ºSemestre/SBD/Práticas/Projeto:/custom-conf:ro" `
#   -v pgdata:/var/lib/postgresql/data `
#   postgres:16 `
#   -c config_file="/custom-conf/postgresql.conf"
#
# Host: 10.0.2.2
#
# Nº of warehouses: 10
#
# Virtual users to build schema: 4
#
# Driver Script and Virtual User options are by default

# %% [markdown]
# ![Screenshot 2025-05-21 at 15-32-55 682DF00C635A03E203937313 Result.png](<attachment:Screenshot 2025-05-21 at 15-32-55 682DF00C635A03E203937313 Result.png>)

# %% [markdown]
# ![Screenshot 2025-05-21 at 15-33-18 682DF00C635A03E203937313 Transaction Count.png](<attachment:Screenshot 2025-05-21 at 15-33-18 682DF00C635A03E203937313 Transaction Count.png>)

# %% [markdown]
# With another configuration

# %% [markdown]
# shared_buffers = 4GB
# work_mem = 32MB
# maintenance_work_mem = 1GB
# wal_level = minimal
# synchronous_commit = off
# fsync = off
# full_page_writes = off
# wal_buffers = 64MB
# commit_delay = 10000
# max_wal_size = 2GB
# min_wal_size = 128MB
# checkpoint_timeout = 30min
# checkpoint_completion_target = 0.9
# max_connections = 200
# max_worker_processes = 16
# max_parallel_workers = 16
# max_parallel_workers_per_gather = 8
# random_page_cost = 1.0
# effective_cache_size = 6GB
# log_min_duration_statement = 1000

# %% [markdown]
# Host: 10.0.2.2
#
# Nº of warehouses: 10
#
# Virtual users to build schema: 4
#
# Driver Script and Virtual User options are by default
